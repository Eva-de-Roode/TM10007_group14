# %%
# Run this to use from colab environment
# !pip install -q --upgrade git+https://github.com/jveenland/tm10007_ml.git

# %%
### Installation of the necessary packages

#general packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets as ds
import seaborn
from scipy import stats
from scipy.cluster.hierarchy import linkage, dendrogram
from sklearn.linear_model import Lasso, LassoCV
from sklearn.preprocessing import LabelEncoder

#classifiers
from sklearn import model_selection
from sklearn import metrics
from sklearn import feature_selection
from sklearn import preprocessing
from sklearn import neighbors
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt


#other imports
from worcliver.load_data import load_data

### Loading the data
data = load_data()

### Division into training and test
amount_in_training = round(len(data.index)*0.8)
amount_in_test = round(len(data.index)*0.2)

#split the data into training data and test data
training_data, test_data = model_selection.train_test_split(data, test_size=(amount_in_test) / len(data), random_state=42)

#checking the lengths
print(f'Training + validation: {len(training_data)} samples, Test: {len(test_data)} samples.')
print(f'So total number of samples: {len(training_data)+len(test_data)}')

### Data inspection: only on the training set!

print(f'The number of samples: {len(training_data.index)}')
print(f'The number of columns: {len(training_data.columns)}')

training_data_df = pd.DataFrame(training_data)
print(training_data_df.info())
cat_cols = training_data_df.select_dtypes(include=["object"]).columns
num_cols = training_data_df.select_dtypes(include=["number"]).columns
print(f"categorical columns: {len(cat_cols)}")
print(f'numerical columns: {len(num_cols)}')

no_variation_samples = 0
for sample in training_data.index:
    data_sample = training_data.drop(columns=['label'])
    if data_sample.loc[sample].max() == data_sample.loc[sample].min():
        no_variation_samples += 1
no_variation_col = 0
for feature in training_data.columns:
    if training_data[feature].max() == training_data[feature].min():
        no_variation_col += 1
print(f'samples with no variation: {no_variation_samples}')
print(f'columns with no variation: {no_variation_col}')

label = training_data[['label']]
malignant_count = (label == "malignant").sum()
benign_count = (label == "benign").sum()

print(f'Class Distribution: malignant {malignant_count} and benign {benign_count}')
# Out:
# Training + validation: 149 samples, Test: 37 samples.
# So total number of samples: 186
# The number of samples: 149
# The number of columns: 494
# <class 'pandas.core.frame.DataFrame'>
# Index: 149 entries, Liver-030_0 to Liver-103_0
# Columns: 494 entries, label to PREDICT_original_phasef_phasesym_entropy_WL3_N5
# dtypes: float64(468), int64(25), object(1)
# memory usage: 576.2+ KB
# None
# categorical columns: 1
# numerical columns: 493
# samples with no variation: 0
# columns with no variation: 19
# Class Distribution: malignant label    76
# dtype: int64 and benign label    73
# dtype: int64

# %% [markdown]
# ## Preprocessing
# The function definitions of the functions used for preprocessing.

# %%
### Some functions for the preprocessing of the data, decisions made based on training set results

# def determining_labels(training_data):
#     '''function definition'''
#     label_training = training_data[['label']]
#     training_data.drop(columns=['label'], inplace=True)

#     label_training_binary = label_training.copy()
#     label_training_binary['label'] = label_training_binary['label'].map({'malignant': 1, 'benign': 0})
    
#     return label_training_binary

def determining_labels(df):
    """Extracts and binarizes labels, and removes the label column from the input DataFrame."""
    
    if 'label' not in df.columns:
        raise KeyError("Expected 'label' column not found in DataFrame.")

    # Copy label column safely
    label_column = df['label'].copy()

    # Drop label from the input DataFrame without modifying the original
    df.drop(columns=['label'], inplace=True)

    # Convert to binary labels
    label_binary = label_column.map({'malignant': 1, 'benign': 0})

    return label_binary

def handling_missing_data(training_data):
    '''function definition'''
    data_training = pd.DataFrame(training_data)

    #if missing data is stored as NaN, replace with the mean
    nan_check = data_training.isna()
    nan_counts = nan_check.sum()
    missing_data_features = nan_counts[nan_counts > 0].index.tolist()

    for feature in missing_data_features:
        mean_value = data_training[feature].mean()
        data_training[feature].fillna(mean_value, inplace=True)
    
    #if missing data is stored as 0, don't handle this as missing data: values in Radiomics can also be determined as 0, so 
    #it cannot be stated that 0 is a missing value. 

    return data_training

def shapiro_wilk_testing(data_training):
    '''function definition'''
    shapiro_results = {}
    no_variation = 0
    features_no_variation = []

    for feature in data_training.columns:
        if data_training[feature].max() == data_training[feature].min():
            shapiro_results[feature] = None  #skipping the feature when there is no variation
            no_variation += 1
            features_no_variation.append(feature)
        else:
            #Shapiro-Wilk test to check for normality
            stat, p_value = stats.shapiro(data_training[feature])

            #if normally distributed, store 1, else store 0
            if p_value > 0.05:
                result = 1
            else:
                result = 0

            shapiro_results[feature] = result

    return features_no_variation, shapiro_results

def normal_distributed_data(shapiro_results): #only relevant on training data, this determines the next steps!
    '''function definition'''
    if sum(1 for result in shapiro_results.values() if result == 0) > 0:
        normal_distributed = False
    return normal_distributed
    
def delete_no_varation(data_training, features_no_variation):
    '''function definition'''
    data_training_clean = data_training.drop(columns=features_no_variation)
    return data_training_clean

def standardize_data(data_training_clean, normal_distributed):
    '''function definition'''
    if not normal_distributed:
        scaler = preprocessing.StandardScaler()
        data_training_standardized = scaler.fit_transform(data_training_clean)
    else:
        data_training_standardized = data_training_clean

    data_training_standardized_df = pd.DataFrame(data_training_standardized, columns=data_training_clean.columns)
    return data_training_standardized_df

# %% [markdown]
# ## Feature extraction
# The function definitions of the functions used for feature extraction.

# %%
### Univariate selection

def univariate_feature_selection(data_training_normalized_df):
    '''function definition'''
    corr_matrix = data_training_normalized_df.corr()

    #step 1: calculate the correlation and associated p-value for every feature-pair
    corr_matrix = pd.DataFrame(index=data_training_normalized_df.columns, columns=data_training_normalized_df.columns, dtype=float)
    pval_matrix = pd.DataFrame(index=data_training_normalized_df.columns, columns=data_training_normalized_df.columns, dtype=float)

    for col1 in data_training_normalized_df.columns:
        for col2 in data_training_normalized_df.columns:
            if col1 == col2:
                corr_matrix.loc[col1, col2] = 1.0
                pval_matrix.loc[col1, col2] = 0.0
            else:
                r, p = stats.pearsonr(data_training_normalized_df[col1], data_training_normalized_df[col2])
                corr_matrix.loc[col1, col2] = r
                pval_matrix.loc[col1, col2] = p


    #step 2: loop through all the feature pairs and determine which ones have a high correlation and low p-value
    threshold = 0.9
    p_threshold = 0.05

    to_drop = set()

    for i, col1 in enumerate(data_training_normalized_df.columns):
        for j, col2 in enumerate(data_training_normalized_df.columns):
            if i >= j:
                continue
            r = corr_matrix.loc[col1, col2]
            p = pval_matrix.loc[col1, col2]

            if abs(r) > threshold and p < p_threshold:
                if col1 not in to_drop and col2 not in to_drop:
                    col_to_drop = col2
                    to_drop.add(col_to_drop)

    print("Dropped features due to high correlation:")
    print(to_drop)

    #step 3: drop one of the features in a feature pair with high correlation and low p-value
    data_training_reduced = data_training_normalized_df.drop(columns=to_drop)

    print(f"Size of new training data set is:{data_training_reduced.shape}; Old was: {data_training_normalized_df.shape}")
    return data_training_reduced


def lasso_feature_selection(data_training_reduced, label_training_binary):
    '''function definition'''
    label_training_array = label_training_binary.values.flatten()

    #step 1: perform Lasso with cross-validation for 50 values of alpha on 10 segments over 10.000 iterations
    lasso_cv = LassoCV(alphas=np.logspace(-4, 0, 100), cv=10, max_iter=10000)  
    lasso_cv.fit(data_training_reduced, label_training_array)

    #step 2: find the best alpha value
    best_alpha = lasso_cv.alpha_
    print(f"Optimal Alpha: {best_alpha}")

    #step 3: fit LASSO again with optimal alpha
    lasso_opt = Lasso(alpha=best_alpha)
    lasso_opt.fit(data_training_reduced, label_training_array)

    #step 4: get the features of interest, and only extract those
    selected_features = data_training_reduced.columns[lasso_opt.coef_ != 0]
    print(f"Number of selected features: {len(selected_features)}")
    print(f"Final Selected Features: {list(selected_features)} ")

    training_data_selected = data_training_reduced[selected_features]
    training_data_selected_df = pd.DataFrame(training_data_selected)

    print(f"Size of new training data set is:{training_data_selected.shape}")
    return training_data_selected_df

# %% [markdown]
# ## Classifiers
#
# ### K-Nearest Neighbours
# Function definition used for the KNN classifier.

# %%
def KNN_classifier(training_data_selected_df, label_training_binary):


    label_training_array = label_training_binary.values.flatten()
    input_knn = training_data_selected_df

    x_train_KNN = input_knn
    y_train_KNN = label_training_array

    x_train_KNN = np.ascontiguousarray(x_train_KNN.values, dtype=np.float64)

    param_grid = {
        'n_neighbors': list(range(1, 31)),
    }   

    # Initialize the classifier
    knn = KNeighborsClassifier()
    cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    # GridSearchCV to find the best k
    grid_search = model_selection.GridSearchCV(knn, param_grid, cv=cv, scoring='accuracy', n_jobs=-1, verbose=1, return_train_score=True, error_score='raise')

    # Fit model
    grid_search.fit(x_train_KNN, y_train_KNN)

    # Convert cv_results_ to a DataFrame for easier manipulation
    results_df = pd.DataFrame(grid_search.cv_results_)

    # Vind alle individuele fold score kolommen
    fold_columns = [col for col in results_df.columns if col.startswith("split") and col.endswith("_test_score")]

    # Aantal folds
    n_folds = len(fold_columns)

    # Functie om CI te berekenen per rij
    def compute_confidence_interval(row):
        scores = row[fold_columns].values
        #############################################vanaf hier gaat het mis, scores is leeg
        mean = np.mean(scores)
        std = np.std(scores, ddof=1)  # sample std dev
        ci_halfwidth = stats.norm.ppf(0.975) * std / np.sqrt(n_folds)
        return pd.Series({
            'mean_score': mean,
            'std_score': std,
            'ci_lower': mean - ci_halfwidth,
            'ci_upper': mean + ci_halfwidth
        })

    # Pas toe op elke rij (elke modelconfiguratie)
    ci_df = results_df.apply(compute_confidence_interval, axis=1)

    # Build a DataFrame with all the relevant info
    final_df = pd.concat([
        results_df[['params', 'mean_train_score', 'std_train_score', 'mean_test_score', 'std_test_score']],
        ci_df
    ], axis=1)

    #final_df = pd.concat([results_df['params'], ci_df], axis=1)

    # Print de top 5 met hoogste mean_score
    top_models = final_df.sort_values(by='mean_score', ascending=False).head(5)
    print(top_models)

    #retraining the model with the top parameters
    top_params_KNN = top_models.iloc[0]['params']
    final_KNN_model = KNeighborsClassifier(**top_params_KNN)
    final_KNN_model.fit(x_train_KNN, y_train_KNN)

    return final_KNN_model

# %% [markdown]
# ### Random forest
# Function definition used for the random forest classifier.

# %%
def random_forest_classifier(training_data_selected_df, label_training_binary):
    label_training_array = label_training_binary.values.flatten()
    input_random_forest = training_data_selected_df
    
    X_train_RF = input_random_forest
    y_train_RF = label_training_array

    X_train_RF = np.ascontiguousarray(X_train_RF.values, dtype=np.float64)

    param_grid_RF = {
        'n_estimators': [110, 115, 120],                     #trees
        'max_depth': [5, 8, 13],                         #maximum depth
        'bootstrap': [True],                     #bootstrap on or off >> moet dus True of False zijn, maar aangezien er altijd True kwam dat nu even gelaten voor snelheid runnen
        'min_samples_split': [2, 3, 4, 5],                    #minimum samples required to split
        'min_samples_leaf': [1, 2, 3],                  #minimum samples wat je uiteindelijk in een leaf overhoudt 
        'max_features': ['sqrt', 'log2'],                       #controls the number of features selected, can also try log2 
        'min_impurity_decrease': [0.00001, 0.000005, 0.00002]   #controls the minimum amount of impurity reduction required for a split to be created    
    }

    random_forest = RandomForestClassifier(random_state=42)

    #de grid search naar de beste hyperparameters
    grid_search_RF = model_selection.GridSearchCV(random_forest, param_grid_RF, cv=10, scoring='accuracy', n_jobs=-1, verbose=1)
    #grid_search = RandomizedSearchCV(random_forest, param_grid, cv=10, scoring='accuracy', n_iter=20, n_jobs=-1, random_state=42, verbose=1)

    # Fit GridSearchCV to the data
    grid_search_RF.fit(X_train_RF, y_train_RF)

    #find the accuracies per fold
    results_df_RF = pd.DataFrame(grid_search_RF.cv_results_)

    # Vind alle individuele fold score kolommen
    fold_columns_RF = [col for col in results_df_RF.columns if col.startswith("split") and col.endswith("_test_score")]

    # Aantal folds
    n_folds_RF = len(fold_columns_RF)

    # Functie om CI te berekenen per rij
    def compute_confidence_interval_RF(row):
        scores = row[fold_columns_RF].values
        mean = np.mean(scores)
        std = np.std(scores, ddof=1)  # sample std dev
        ci_halfwidth = stats.norm.ppf(0.975) * std / np.sqrt(n_folds_RF)
        return pd.Series({
            'mean_score': mean,
            'std_score': std,
            'ci_lower': mean - ci_halfwidth,
            'ci_upper': mean + ci_halfwidth
        })

    # Pas toe op elke rij (elke modelconfiguratie)
    ci_RF = results_df_RF.apply(compute_confidence_interval_RF, axis=1)

    # Combineer met de parameterinstellingen
    final_RF = pd.concat([results_df_RF['params'], ci_RF], axis=1)

    # Print de top 5 met hoogste mean_score
    top_models_RF = final_RF.sort_values(by='mean_score', ascending=False).head(5)

    pd.set_option('display.max_colwidth', None)
    print(top_models_RF)

    #retraining the model with the top parameters
    top_params_RF = top_models_RF.iloc[0]['params']
    final_RF_model = RandomForestClassifier(**top_params_RF, random_state=42)
    final_RF_model.fit(X_train_RF, y_train_RF)

    return final_RF_model

# %% [markdown]
# ### Support vector machine
# Function definition used for the support vector machine classifier.

# %%
def SVM_classifier(training_data_selected_df, label_training_binary):
    label_training_array = label_training_binary.values.flatten()
    input_SVM = training_data_selected_df

    X_train_SVM = input_SVM
    y_train_SVM = label_training_array

    X_train_SVM = np.ascontiguousarray(X_train_SVM.values, dtype=np.float64)

    param_grid_SVM = {
        'kernel': ['linear', 'poly', 'rbf'],        # kernel-types
        'C': [0.01, 0.1, 1, 2, 3, 5, 10, 100],      # Expand the range of C values
        'gamma': ['scale', 'auto', 0.01, 0.05, 0.1, 0.2, 0.5], # Add more gamma values
        'degree': [1, 3, 5, 10, 12, 15],            # Add more degree values for polynomial kernel
        'coef0': [0.0, 0.01, 0.5, 1, 2]             # Extend coef0 range
    }

    SVM_model = SVC()

    #de grid search naar de beste hyperparameters
    grid_search_SVM = model_selection.GridSearchCV(SVM_model, param_grid_SVM, cv=10, scoring='accuracy', n_jobs=-1, verbose=1)
    #grid_search = RandomizedSearchCV(random_forest, param_grid, cv=10, scoring='accuracy', n_iter=20, n_jobs=-1, random_state=42, verbose=1)

    # Fit GridSearchCV to the data
    grid_search_SVM.fit(X_train_SVM, y_train_SVM)

    #find the accuracies per fold
    results_df_SVM = pd.DataFrame(grid_search_SVM.cv_results_)

    # Vind alle individuele fold score kolommen
    fold_columns_SVM = [col for col in results_df_SVM.columns if col.startswith("split") and col.endswith("_test_score")]

    # Aantal folds
    n_folds_SVM = len(fold_columns_SVM)

    # Functie om CI te berekenen per rij
    def compute_confidence_interval_SVM(row):
        scores = row[fold_columns_SVM].values
        mean = np.mean(scores)
        std = np.std(scores, ddof=1)  # sample std dev
        ci_halfwidth = stats.norm.ppf(0.975) * std / np.sqrt(n_folds_SVM)
        return pd.Series({
            'mean_score': mean,
            'std_score': std,
            'ci_lower': mean - ci_halfwidth,
            'ci_upper': mean + ci_halfwidth
        })

    # Pas toe op elke rij (elke modelconfiguratie)
    ci_SVM = results_df_SVM.apply(compute_confidence_interval_SVM, axis=1)

    # Combineer met de parameterinstellingen
    final_SVM = pd.concat([results_df_SVM['params'], ci_SVM], axis=1)

    # Print de top 5 met hoogste mean_score
    top_models_SVM = final_SVM.sort_values(by='mean_score', ascending=False).head(5)
    pd.set_option('display.max_colwidth', None)
    print(top_models_SVM)

    #retraining the model with the top parameters
    top_params_SVM = top_models_SVM.iloc[0]['params']
    final_SVM_model = SVC(**top_params_SVM)
    final_SVM_model.fit(X_train_SVM, y_train_SVM)

    return final_SVM_model

# %% [markdown]
# ### Creating the machine learning models and testing it

# %%
### Loading the data
data = load_data()

### Division into training and test
amount_in_training = round(len(data.index)*0.8)
amount_in_test = round(len(data.index)*0.2)

results = []
roc_data = {
    "KNN": [],
    "RF": [],
    "SVM": [],
    "KNN + LASSO": [],
    "RF + LASSO": [],
    "SVM + LASSO": []
}

# #split the data into training data and test data
# for i in range(5):
#     training_data, test_data = model_selection.train_test_split(
#         data, test_size=(amount_in_test) / len(data), random_state=np.random.randint(10000)
#     )

for i in range(5):
    # Work with a *copy* of the full dataset each time
    full_data = data.copy()

    training_data, test_data = model_selection.train_test_split(
        full_data, test_size=(amount_in_test) / len(full_data), random_state=np.random.randint(10000)
    )
    
    ### Preprocessing the training data
    label_training_binary = determining_labels(training_data)
    data_training = handling_missing_data(training_data)
    features_no_variation, shapiro_results = shapiro_wilk_testing(data_training)
    normal_distributed = normal_distributed_data(shapiro_results)
    data_training_clean = delete_no_varation(data_training, features_no_variation)
    data_training_normalized_df = standardize_data(data_training_clean, normal_distributed)

    ### Preprocessing the test data
    label_test_binary = determining_labels(test_data)
    data_test = handling_missing_data(test_data)
    data_test_clean = delete_no_varation(data_test, features_no_variation)
    data_test_normalized_df = standardize_data(data_test_clean, normal_distributed)

    ### Preprocessing all the data together (needed for learning curves)
    label_binary = determining_labels(full_data)
    full_data_clean = handling_missing_data(full_data)
    data_clean = delete_no_varation(full_data_clean, features_no_variation)
    data_normalized_df = standardize_data(data_clean, normal_distributed)

    ### Feature selection
    data_training_univariate = univariate_feature_selection(data_training_normalized_df)
    training_data_selected_df = lasso_feature_selection(data_training_univariate, label_training_binary)

    ### Training the classifiers
    final_KNN_model_LASSO = KNN_classifier(training_data_selected_df, label_training_binary)
    final_RF_model_LASSO = random_forest_classifier(training_data_selected_df, label_training_binary)
    final_SVM_model_LASSO = SVM_classifier(training_data_selected_df, label_training_binary)

    final_KNN_model = KNN_classifier(data_training_univariate, label_training_binary)
    final_RF_model = random_forest_classifier(data_training_univariate, label_training_binary)
    final_SVM_model = SVM_classifier(data_training_univariate, label_training_binary)

    #accuracy of the prediction of the test set
    y_test = label_test_binary.values.flatten()
    X_test_LASSO = data_test_normalized_df.reset_index(drop=True)[training_data_selected_df.columns]
    X_test_LASSO = np.ascontiguousarray(X_test_LASSO.values, dtype=np.float64)
    X_test = data_test_normalized_df.reset_index(drop=True)[data_training_univariate.columns]
    X_test = np.ascontiguousarray(X_test.values, dtype=np.float64)

    result_row = []

    for model, X in [(final_KNN_model, X_test), (final_RF_model, X_test), (final_SVM_model, X_test),
                     (final_KNN_model_LASSO, X_test_LASSO), (final_RF_model_LASSO, X_test_LASSO), (final_SVM_model_LASSO, X_test_LASSO)]:
        y_pred = model.predict(X)
        acc = accuracy_score(y_test, y_pred)
        auc = roc_auc_score(y_test, y_pred)
        result_row.extend([acc, auc])

    results.append(result_row)

    models_info = {
        "KNN": (final_KNN_model, X_test),
        "RF": (final_RF_model, X_test),
        "SVM": (final_SVM_model, X_test),
        "KNN + LASSO": (final_KNN_model_LASSO, X_test_LASSO),
        "RF + LASSO": (final_RF_model_LASSO, X_test_LASSO),
        "SVM + LASSO": (final_SVM_model_LASSO, X_test_LASSO)
    }

    for label, (model, X_input) in models_info.items():
        if hasattr(model, "predict_proba"):
            y_score = model.predict_proba(X_input)[:, 1]
        elif hasattr(model, "decision_function"):
            y_score = model.decision_function(X_input)
        else:
            y_score = model.predict(X_input)
        fpr, tpr, _ = roc_curve(y_test, y_score)
        roc_data[label].append((fpr, tpr))

# Convert to numpy array for easier handling
results_array = np.array(results)

# Optional: show as DataFrame for readability
import pandas as pd
columns = [
    "KNN_Acc", "KNN_AUC", "RF_Acc", "RF_AUC", "SVM_Acc", "SVM_AUC",
    "KNN_LASSO_Acc", "KNN_LASSO_AUC", "RF_LASSO_Acc", "RF_LASSO_AUC", "SVM_LASSO_Acc", "SVM_LASSO_AUC"
]
results_df = pd.DataFrame(results_array, columns=columns)
print(results_df)

# # === Plotting ROC curves ===
# for label, curves in roc_data.items():
#     plt.figure(figsize=(8, 6))
#     for i, (fpr, tpr) in enumerate(curves):
#         roc_auc = auc(fpr, tpr)
#         plt.plot(fpr, tpr, lw=2, label=f'Split {i+1} (AUC = {roc_auc:.2f})')
#     plt.plot([0, 1], [0, 1], 'k--', lw=1)
#     plt.title(f'ROC Curve - {label}')
#     plt.xlabel('False Positive Rate')
#     plt.ylabel('True Positive Rate')
#     plt.legend(loc='lower right')
#     plt.grid(True)
#     plt.tight_layout()
#     plt.show()
# Out:
# Dropped features due to high correlation:
# {'PREDICT_original_vf_Frangi_inner_kurtosis_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_Gabor_range_F0.5_A1.57', 'PREDICT_original_tf_GLCMMS_contrastd3.0A0.79std', 'PREDICT_original_phasef_phasecong_range_WL3_N5', 'PREDICT_original_tf_GLCMMS_energyd3.0A0.0std', 'PREDICT_original_tf_GLCMMS_contrastd1.0A1.57std', 'PREDICT_original_tf_GLCMMS_correlationd3.0A0.79mean', 'PREDICT_original_vf_Frangi_full_quartile_range_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_phasef_phasesym_std_WL3_N5', 'PREDICT_original_phasef_phasecong_quartile_range_WL3_N5', 'PREDICT_original_tf_GLCMMS_ASMd3.0A0.79mean', 'PREDICT_original_tf_Gabor_range_F0.5_A0.0', 'PREDICT_original_tf_GLCMMS_dissimilarityd3.0A0.79mean', 'PREDICT_original_tf_Gabor_entropy_F0.2_A0.79', 'PREDICT_original_vf_Frangi_edge_quartile_range_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCMMS_ASMd3.0A0.0std', 'PREDICT_original_tf_Gabor_range_F0.05_A2.36', 'PREDICT_original_tf_Gabor_peak_F0.5_A1.57', 'PREDICT_original_tf_Gabor_entropy_F0.2_A2.36', 'PREDICT_original_tf_GLCMMS_contrastd1.0A2.36std', 'PREDICT_original_logf_entropy_sigma1', 'PREDICT_original_tf_Gabor_entropy_F0.05_A1.57', 'PREDICT_original_tf_GLCM_dissimilarityd3.0A0.0', 'PREDICT_original_tf_GLCM_ASMd1.0A2.36', 'PREDICT_original_tf_GLCMMS_energyd1.0A1.57std', 'PREDICT_original_phasef_monogenic_peak_position_WL3_N5', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57mean', 'PREDICT_original_tf_GLCMMS_correlationd1.0A0.79mean', 'PREDICT_original_tf_GLCM_dissimilarityd1.0A0.0', 'PREDICT_original_tf_GLCMMS_correlationd1.0A2.36mean', 'PREDICT_original_tf_Gabor_std_F0.05_A0.0', 'PREDICT_original_tf_GLCM_homogeneityd1.0A1.57', 'PREDICT_original_tf_GLCMMS_contrastd1.0A0.79std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A1.57std', 'PREDICT_original_tf_GLCM_ASMd3.0A1.57', 'PREDICT_original_tf_Gabor_std_F0.2_A0.79', 'PREDICT_original_tf_GLCMMS_correlationd1.0A1.57std', 'PREDICT_original_tf_GLCMMS_energyd3.0A2.36std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A0.0std', 'PREDICT_original_tf_Gabor_std_F0.2_A2.36', 'PREDICT_original_tf_Gabor_entropy_F0.5_A0.79', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A0.0std', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57std', 'PREDICT_original_hf_std', 'PREDICT_original_tf_GLCM_energyd1.0A0.0', 'PREDICT_original_tf_GLCMMS_ASMd1.0A2.36std', 'PREDICT_original_tf_Gabor_std_F0.5_A0.79', 'PREDICT_original_tf_GLCMMS_energyd1.0A0.79mean', 'PREDICT_original_tf_LBP_entropy_R8_P24', 'PREDICT_original_tf_GLCMMS_contrastd3.0A0.0std', 'PREDICT_original_tf_GLCM_contrastd3.0A0.0', 'PREDICT_original_tf_Gabor_quartile_range_F0.5_A1.57', 'PREDICT_original_tf_GLCMMS_dissimilarityd3.0A1.57std', 'PREDICT_original_tf_GLCMMS_correlationd1.0A0.0mean', 'PREDICT_original_tf_Gabor_min_F0.5_A2.36', 'PREDICT_original_hf_entropy', 'PREDICT_original_tf_GLCM_contrastd1.0A2.36', 'PREDICT_original_tf_GLCMMS_contrastd3.0A2.36std', 'PREDICT_original_tf_LBP_quartile_range_R8_P24', 'PREDICT_original_tf_Gabor_entropy_F0.5_A0.0', 'PREDICT_original_tf_GLCM_correlationd1.0A1.57', 'PREDICT_original_tf_GLCM_ASMd1.0A0.79', 'PREDICT_original_tf_GLCM_homogeneityd3.0A0.0', 'PREDICT_original_tf_GLCMMS_dissimilarityd3.0A2.36std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A1.57mean', 'PREDICT_original_tf_Gabor_entropy_F0.2_A1.57', 'PREDICT_original_tf_Gabor_range_F0.05_A0.0', 'PREDICT_original_tf_GLCMMS_correlationd1.0A1.57mean', 'PREDICT_original_tf_Gabor_std_F0.05_A2.36', 'PREDICT_original_vf_Frangi_inner_std_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCM_homogeneityd1.0A2.36', 'PREDICT_original_phasef_phasecong_kurtosis_WL3_N5', 'PREDICT_original_tf_GLCMMS_dissimilarityd1.0A0.79std', 'PREDICT_original_tf_GLCM_dissimilarityd3.0A2.36', 'PREDICT_original_tf_Gabor_std_F0.2_A0.0', 'PREDICT_original_tf_Gabor_peak_F0.5_A0.79', 'PREDICT_original_tf_Gabor_std_F0.05_A1.57', 'PREDICT_original_sf_area_max_2.5D', 'PREDICT_original_tf_GLCM_correlationd3.0A1.57', 'PREDICT_original_vf_Frangi_edge_median_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_Gabor_std_F0.05_A0.79', 'PREDICT_original_tf ...
# Size of new training data set is:(149, 224); Old was: (149, 474)
# Optimal Alpha: 0.04229242874389499
# Number of selected features: 27
# Final Selected Features: ['PREDICT_original_sf_prax_avg_2.5D', 'PREDICT_original_sf_area_avg_2.5D', 'PREDICT_original_sf_area_min_2.5D', 'PREDICT_original_logf_median_sigma1', 'PREDICT_original_logf_kurtosis_sigma1', 'PREDICT_original_logf_quartile_range_sigma1', 'PREDICT_original_logf_std_sigma5', 'PREDICT_original_logf_quartile_range_sigma5', 'PREDICT_original_logf_median_sigma10', 'PREDICT_original_logf_skewness_sigma10', 'PREDICT_original_tf_LBP_std_R3_P12', 'PREDICT_original_tf_LBP_mean_R8_P24', 'PREDICT_original_tf_GLCMMS_correlationd3.0A0.0std', 'PREDICT_original_tf_GLCMMS_correlationd3.0A1.57std', 'PREDICT_original_tf_Gabor_min_F0.05_A2.36', 'PREDICT_original_tf_Gabor_peak_F0.05_A2.36', 'PREDICT_original_tf_Gabor_quartile_range_F0.05_A2.36', 'PREDICT_original_tf_Gabor_skewness_F0.2_A0.0', 'PREDICT_original_tf_Gabor_kurtosis_F0.2_A0.0', 'PREDICT_original_tf_Gabor_mean_F0.2_A1.57', 'PREDICT_original_tf_Gabor_peak_F0.2_A1.57', 'PREDICT_original_tf_Gabor_skewness_F0.5_A0.0', 'PREDICT_original_tf_Gabor_quartile_range_F0.5_A0.0', 'PREDICT_original_vf_Frangi_full_entropy_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_phasef_monogenic_peak_WL3_N5', 'PREDICT_original_phasef_phasecong_entropy_WL3_N5', 'PREDICT_original_phasef_phasesym_median_WL3_N5']
# Size of new training data set is:(149, 27)
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
#                  params  mean_train_score  std_train_score  mean_test_score  \
# 10  {'n_neighbors': 11}          0.847877         0.020874         0.792857
# 12  {'n_neighbors': 13}          0.836711         0.022556         0.786190
# 9   {'n_neighbors': 10}          0.855345         0.014846         0.785714
# 23  {'n_neighbors': 24}          0.797164         0.018236         0.779524
# 8    {'n_neighbors': 9}          0.850122         0.013822         0.779524
#
#     std_test_score  mean_score  std_score  ci_lower  ci_upper
# 10        0.116628    0.792857   0.122936  0.716662  0.869053
# 12        0.114096    0.786190   0.120268  0.711649  0.860732
# 9         0.125212    0.785714   0.131985  0.703911  0.867518
# 23        0.088884    0.779524   0.093692  0.721454  0.837594
# 8         0.102796    0.779524   0.108357  0.712365  0.846683
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
#                                                                                                                                                                params  \
# 435  {'bootstrap': True, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 110}
# 471  {'bootstrap': True, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 110}
# 509  {'bootstrap': True, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 120}
# 508  {'bootstrap': True, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 115}
# 473  {'bootstrap': True, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 120}
#
#      mean_score  std_score  ci_lower  ci_upper
# 435    0.772857   0.137098  0.687884   0.85783
# 471    0.772857   0.137098  0.687884   0.85783
# 509    0.772857   0.137098  0.687884   0.85783
# 508    0.772857   0.137098  0.687884   0.85783
# 473    0.772857   0.137098  0.687884   0.85783
# Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#                                                                           params  \
# 2800        {'C': 3, 'coef0': 0.5, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 591   {'C': 0.01, 'coef0': 2, 'degree': 12, 'gamma': 'auto', 'kernel': 'linear'}
# 285     {'C': 0.01, 'coef0': 0.5, 'degree': 3, 'gamma': 0.1, 'kernel': 'linear'}
# 1147         {'C': 0.1, 'coef0': 2, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# 282    {'C': 0.01, 'coef0': 0.5, 'degree': 3, 'gamma': 0.05, 'kernel': 'linear'}
#
#       mean_score  std_score  ci_lower  ci_upper
# 2800    0.839048   0.084046  0.786956  0.891139
# 591     0.832857   0.077906  0.784572  0.881143
# 285     0.832857   0.077906  0.784572  0.881143
# 1147    0.832857   0.077906  0.784572  0.881143
# 282     0.832857   0.077906  0.784572  0.881143
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
#                  params  mean_train_score  std_train_score  mean_test_score  \
# 8    {'n_neighbors': 9}          0.723339         0.013561         0.665714
# 3    {'n_neighbors': 4}          0.758391         0.023381         0.659048
# 2    {'n_neighbors': 3}          0.815815         0.015588         0.652381
# 10  {'n_neighbors': 11}          0.712172         0.022925         0.651905
# 7    {'n_neighbors': 8}          0.719602         0.015886         0.645238
#
#     std_test_score  mean_score  std_score  ci_lower  ci_upper
# 8         0.113844    0.665714   0.120003  0.591337  0.740091
# 3         0.122986    0.659048   0.129639  0.578698  0.739397
# 2         0.140956    0.652381   0.148580  0.560292  0.744470
# 10        0.116807    0.651905   0.123125  0.575593  0.728217
# 7         0.092269    0.645238   0.097260  0.584957  0.705520
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
#                                                                                                                                                                params  \
# 600  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 110}
# 567  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 110}
# 573  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 110}
# 606  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 110}
# 564  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 110}
#
#      mean_score  std_score  ci_lower  ci_upper
# 600    0.733333   0.180534  0.621439  0.845228
# 567    0.733333   0.180534  0.621439  0.845228
# 573    0.733333   0.180534  0.621439  0.845228
# 606    0.733333   0.180534  0.621439  0.845228
# 564    0.733333   0.180534  0.621439  0.845228
# Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#                                                                         params  \
# 1156   {'C': 0.1, 'coef0': 2, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 1159    {'C': 0.1, 'coef0': 2, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 1261   {'C': 1, 'coef0': 0.0, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 1765     {'C': 1, 'coef0': 2, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 1387  {'C': 1, 'coef0': 0.01, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
#
#       mean_score  std_score  ci_lower  ci_upper
# 1156    0.812381   0.102776  0.748681  0.876081
# 1159    0.812381   0.102776  0.748681  0.876081
# 1261    0.792381   0.105653  0.726898  0.857864
# 1765    0.792381   0.105653  0.726898  0.857864
# 1387    0.792381   0.105653  0.726898  0.857864
# Dropped features due to high correlation:
# {'PREDICT_original_vf_Frangi_inner_kurtosis_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_Gabor_range_F0.5_A1.57', 'PREDICT_original_tf_GLCMMS_contrastd3.0A0.79std', 'PREDICT_original_tf_GLCMMS_energyd3.0A0.0std', 'PREDICT_original_tf_GLCMMS_contrastd1.0A1.57std', 'PREDICT_original_tf_GLCMMS_correlationd3.0A0.79mean', 'PREDICT_original_vf_Frangi_full_quartile_range_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_phasef_phasesym_std_WL3_N5', 'PREDICT_original_phasef_phasecong_quartile_range_WL3_N5', 'PREDICT_original_tf_GLCMMS_ASMd3.0A0.79mean', 'PREDICT_original_tf_Gabor_range_F0.5_A0.0', 'PREDICT_original_tf_GLCMMS_dissimilarityd3.0A0.79mean', 'PREDICT_original_logf_energy_sigma10', 'PREDICT_original_tf_Gabor_entropy_F0.2_A0.79', 'PREDICT_original_vf_Frangi_edge_quartile_range_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCMMS_ASMd3.0A0.0std', 'PREDICT_original_tf_Gabor_range_F0.05_A2.36', 'PREDICT_original_tf_Gabor_entropy_F0.2_A2.36', 'PREDICT_original_tf_GLCMMS_contrastd1.0A2.36std', 'PREDICT_original_logf_entropy_sigma1', 'PREDICT_original_tf_Gabor_entropy_F0.05_A1.57', 'PREDICT_original_tf_GLCM_dissimilarityd3.0A0.0', 'PREDICT_original_tf_GLCM_ASMd1.0A2.36', 'PREDICT_original_tf_GLCMMS_energyd1.0A1.57std', 'PREDICT_original_phasef_monogenic_peak_position_WL3_N5', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57mean', 'PREDICT_original_tf_GLCMMS_correlationd1.0A0.79mean', 'PREDICT_original_tf_GLCM_dissimilarityd1.0A0.0', 'PREDICT_original_tf_GLCMMS_correlationd1.0A2.36mean', 'PREDICT_original_tf_Gabor_std_F0.05_A0.0', 'PREDICT_original_tf_GLCM_homogeneityd1.0A1.57', 'PREDICT_original_tf_GLCMMS_contrastd1.0A0.79std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A1.57std', 'PREDICT_original_tf_GLCM_ASMd3.0A1.57', 'PREDICT_original_tf_Gabor_std_F0.2_A0.79', 'PREDICT_original_tf_GLCMMS_correlationd1.0A1.57std', 'PREDICT_original_tf_GLCMMS_energyd3.0A2.36std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A0.0std', 'PREDICT_original_tf_Gabor_std_F0.2_A2.36', 'PREDICT_original_tf_Gabor_entropy_F0.5_A0.79', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A0.0std', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57std', 'PREDICT_original_hf_std', 'PREDICT_original_tf_GLCM_energyd1.0A0.0', 'PREDICT_original_tf_GLCMMS_ASMd1.0A2.36std', 'PREDICT_original_tf_Gabor_std_F0.5_A0.79', 'PREDICT_original_vf_Frangi_inner_entropy_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCMMS_energyd1.0A0.79mean', 'PREDICT_original_tf_LBP_entropy_R8_P24', 'PREDICT_original_tf_GLCMMS_contrastd3.0A0.0std', 'PREDICT_original_tf_GLCM_contrastd3.0A0.0', 'PREDICT_original_tf_Gabor_quartile_range_F0.5_A1.57', 'PREDICT_original_tf_GLCMMS_correlationd1.0A0.0mean', 'PREDICT_original_tf_Gabor_min_F0.5_A2.36', 'PREDICT_original_hf_entropy', 'PREDICT_original_tf_GLCM_contrastd1.0A2.36', 'PREDICT_original_tf_GLCMMS_contrastd3.0A2.36std', 'PREDICT_original_tf_LBP_quartile_range_R8_P24', 'PREDICT_original_tf_Gabor_entropy_F0.5_A0.0', 'PREDICT_original_tf_GLCM_correlationd1.0A1.57', 'PREDICT_original_tf_GLCM_ASMd1.0A0.79', 'PREDICT_original_tf_GLCM_homogeneityd3.0A0.0', 'PREDICT_original_tf_GLCMMS_ASMd1.0A1.57mean', 'PREDICT_original_tf_Gabor_entropy_F0.2_A1.57', 'PREDICT_original_tf_Gabor_range_F0.05_A0.0', 'PREDICT_original_tf_GLCMMS_correlationd1.0A1.57mean', 'PREDICT_original_tf_Gabor_std_F0.05_A2.36', 'PREDICT_original_vf_Frangi_inner_std_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCM_homogeneityd1.0A2.36', 'PREDICT_original_phasef_phasecong_kurtosis_WL3_N5', 'PREDICT_original_tf_GLCMMS_dissimilarityd1.0A0.79std', 'PREDICT_original_tf_GLCM_dissimilarityd3.0A2.36', 'PREDICT_original_tf_Gabor_energy_F0.5_A1.57', 'PREDICT_original_tf_Gabor_std_F0.2_A0.0', 'PREDICT_original_tf_Gabor_peak_F0.5_A0.79', 'PREDICT_original_tf_Gabor_std_F0.05_A1.57', 'PREDICT_original_tf_GLCM_correlationd3.0A1.57', 'PREDICT_original_tf_Gabor_max_F0.2_A1.57', 'PREDICT_original_vf_Frangi_edge_median_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_Gabor_std_F0.05_A0.79', 'PREDICT_original_tf_LBP_kurtosis_R8_P24', 'PREDICT_original_tf_GLCMM ...
# Size of new training data set is:(149, 220); Old was: (149, 476)
# Optimal Alpha: 0.02915053062825179
# Number of selected features: 40
# Final Selected Features: ['PREDICT_original_sf_roughness_std_2.5D', 'PREDICT_original_sf_prax_avg_2.5D', 'PREDICT_original_sf_prax_std_2.5D', 'PREDICT_original_sf_evar_avg_2.5D', 'PREDICT_original_sf_area_max_2.5D', 'PREDICT_original_sf_area_min_2.5D', 'PREDICT_original_of_theta_z', 'PREDICT_original_logf_median_sigma1', 'PREDICT_original_logf_kurtosis_sigma1', 'PREDICT_original_logf_quartile_range_sigma1', 'PREDICT_original_logf_median_sigma5', 'PREDICT_original_logf_std_sigma5', 'PREDICT_original_logf_median_sigma10', 'PREDICT_original_logf_skewness_sigma10', 'PREDICT_original_logf_peak_sigma10', 'PREDICT_original_tf_LBP_std_R3_P12', 'PREDICT_original_tf_LBP_energy_R3_P12', 'PREDICT_original_tf_LBP_mean_R8_P24', 'PREDICT_original_tf_GLCMMS_correlationd3.0A1.57std', 'PREDICT_original_tf_Gabor_kurtosis_F0.05_A0.79', 'PREDICT_original_tf_Gabor_min_F0.05_A2.36', 'PREDICT_original_tf_Gabor_peak_F0.05_A2.36', 'PREDICT_original_tf_Gabor_quartile_range_F0.05_A2.36', 'PREDICT_original_tf_Gabor_skewness_F0.2_A0.0', 'PREDICT_original_tf_Gabor_kurtosis_F0.2_A0.79', 'PREDICT_original_tf_Gabor_mean_F0.2_A1.57', 'PREDICT_original_tf_Gabor_peak_F0.2_A1.57', 'PREDICT_original_tf_Gabor_min_F0.2_A2.36', 'PREDICT_original_tf_Gabor_skewness_F0.5_A0.0', 'PREDICT_original_tf_Gabor_quartile_range_F0.5_A0.0', 'PREDICT_original_tf_Gabor_peak_position_F0.5_A0.79', 'PREDICT_original_tf_Gabor_mean_F0.5_A1.57', 'PREDICT_original_tf_Gabor_kurtosis_F0.5_A1.57', 'PREDICT_original_tf_Gabor_peak_F0.5_A2.36', 'PREDICT_original_vf_Frangi_full_min_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_vf_Frangi_full_median_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_vf_Frangi_inner_median_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_vf_Frangi_inner_peak_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_phasef_phasecong_entropy_WL3_N5', 'PREDICT_original_phasef_phasesym_median_WL3_N5']
# Size of new training data set is:(149, 40)
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
#                  params  mean_train_score  std_train_score  mean_test_score  \
# 16  {'n_neighbors': 17}          0.849364         0.022841         0.786190
# 20  {'n_neighbors': 21}          0.836722         0.023411         0.786190
# 22  {'n_neighbors': 23}          0.832980         0.023486         0.779524
# 18  {'n_neighbors': 19}          0.841177         0.016881         0.779524
# 24  {'n_neighbors': 25}          0.826280         0.030560         0.779524
#
#     std_test_score  mean_score  std_score  ci_lower  ci_upper
# 16        0.097275    0.786190   0.102536  0.722639  0.849742
# 20        0.092593    0.786190   0.097602  0.725697  0.846683
# 22        0.098378    0.779524   0.103700  0.715251  0.843796
# 18        0.102796    0.779524   0.108357  0.712365  0.846683
# 24        0.111108    0.779524   0.117118  0.706935  0.852113
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
#                                                                                                                                                                params  \
# 378   {'bootstrap': True, 'max_depth': 8, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 110}
# 372   {'bootstrap': True, 'max_depth': 8, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 110}
# 341   {'bootstrap': True, 'max_depth': 8, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 120}
# 339   {'bootstrap': True, 'max_depth': 8, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 110}
# 624  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 110}
#
#      mean_score  std_score  ci_lower  ci_upper
# 378    0.825238   0.078921  0.776323  0.874153
# 372    0.825238   0.078921  0.776323  0.874153
# 341    0.825238   0.100892  0.762706  0.887770
# 339    0.825238   0.078921  0.776323  0.874153
# 624    0.825238   0.078921  0.776323  0.874153
# Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#                                                                           params  \
# 883    {'C': 0.1, 'coef0': 0.5, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 631    {'C': 0.1, 'coef0': 0.0, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 757   {'C': 0.1, 'coef0': 0.01, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 1135     {'C': 0.1, 'coef0': 2, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 1009     {'C': 0.1, 'coef0': 1, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
#
#       mean_score  std_score  ci_lower  ci_upper
# 883     0.912381   0.064092  0.872657  0.952105
# 631     0.912381   0.064092  0.872657  0.952105
# 757     0.912381   0.064092  0.872657  0.952105
# 1135    0.912381   0.064092  0.872657  0.952105
# 1009    0.912381   0.064092  0.872657  0.952105
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
#                  params  mean_train_score  std_train_score  mean_test_score  \
# 4    {'n_neighbors': 5}          0.782255         0.024671         0.664762
# 2    {'n_neighbors': 3}          0.820276         0.020478         0.651429
# 24  {'n_neighbors': 25}          0.689790         0.026023         0.651429
# 0    {'n_neighbors': 1}          1.000000         0.000000         0.645714
# 28  {'n_neighbors': 29}          0.688325         0.029598         0.645238
#
#     std_test_score  mean_score  std_score  ci_lower  ci_upper
# 4         0.097757    0.664762   0.103045  0.600895  0.728629
# 2         0.075976    0.651429   0.080086  0.601792  0.701065
# 24        0.105383    0.651429   0.111084  0.582579  0.720278
# 0         0.135278    0.645714   0.142596  0.557334  0.734095
# 28        0.092269    0.645238   0.097260  0.584957  0.705520
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
#                                                                                                                                                                params  \
# 577  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 115}
# 613  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 115}
# 541  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 115}
# 320   {'bootstrap': True, 'max_depth': 8, 'max_features': 'sqrt', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 120}
# 530  {'bootstrap': True, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 120}
#
#      mean_score  std_score  ci_lower  ci_upper
# 577    0.758571   0.104667  0.693699  0.823443
# 613    0.758571   0.104667  0.693699  0.823443
# 541    0.758571   0.104667  0.693699  0.823443
# 320    0.758571   0.122089  0.682901  0.834242
# 530    0.758571   0.122089  0.682901  0.834242
# Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#                                                                        params  \
# 772    {'C': 0.1, 'coef0': 0.01, 'degree': 1, 'gamma': 0.2, 'kernel': 'poly'}
# 3151  {'C': 5, 'coef0': 0.0, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 3655    {'C': 5, 'coef0': 2, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 2023    {'C': 2, 'coef0': 0.01, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# 2401       {'C': 2, 'coef0': 2, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
#
#       mean_score  std_score  ci_lower  ci_upper
# 772     0.845238   0.056399  0.810282  0.880194
# 3151    0.845238   0.056399  0.810282  0.880194
# 3655    0.845238   0.056399  0.810282  0.880194
# 2023    0.845238   0.056399  0.810282  0.880194
# 2401    0.845238   0.056399  0.810282  0.880194
# Dropped features due to high correlation:
# {'PREDICT_original_vf_Frangi_inner_kurtosis_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_Gabor_range_F0.5_A1.57', 'PREDICT_original_tf_GLCMMS_contrastd3.0A0.79std', 'PREDICT_original_tf_GLCMMS_energyd3.0A0.0std', 'PREDICT_original_tf_GLCMMS_contrastd1.0A1.57std', 'PREDICT_original_tf_GLCMMS_correlationd3.0A0.79mean', 'PREDICT_original_vf_Frangi_full_quartile_range_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_phasef_phasesym_std_WL3_N5', 'PREDICT_original_phasef_phasecong_quartile_range_WL3_N5', 'PREDICT_original_tf_GLCMMS_ASMd3.0A0.79mean', 'PREDICT_original_tf_Gabor_range_F0.5_A0.0', 'PREDICT_original_tf_GLCMMS_dissimilarityd3.0A0.79mean', 'PREDICT_original_logf_energy_sigma10', 'PREDICT_original_tf_Gabor_entropy_F0.2_A0.79', 'PREDICT_original_vf_Frangi_edge_quartile_range_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCMMS_ASMd3.0A0.0std', 'PREDICT_original_tf_Gabor_range_F0.05_A2.36', 'PREDICT_original_tf_Gabor_peak_F0.5_A1.57', 'PREDICT_original_tf_Gabor_entropy_F0.2_A2.36', 'PREDICT_original_tf_GLCMMS_contrastd1.0A2.36std', 'PREDICT_original_logf_entropy_sigma1', 'PREDICT_original_tf_Gabor_entropy_F0.05_A1.57', 'PREDICT_original_tf_GLCM_dissimilarityd3.0A0.0', 'PREDICT_original_tf_GLCM_ASMd1.0A2.36', 'PREDICT_original_tf_GLCMMS_energyd1.0A1.57std', 'PREDICT_original_phasef_monogenic_peak_position_WL3_N5', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57mean', 'PREDICT_original_tf_GLCMMS_correlationd1.0A0.79mean', 'PREDICT_original_tf_GLCM_dissimilarityd1.0A0.0', 'PREDICT_original_tf_GLCMMS_correlationd1.0A2.36mean', 'PREDICT_original_tf_Gabor_std_F0.05_A0.0', 'PREDICT_original_tf_GLCM_homogeneityd1.0A1.57', 'PREDICT_original_tf_GLCMMS_contrastd1.0A0.79std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A1.57std', 'PREDICT_original_tf_GLCM_ASMd3.0A1.57', 'PREDICT_original_tf_Gabor_std_F0.2_A0.79', 'PREDICT_original_tf_GLCMMS_correlationd1.0A1.57std', 'PREDICT_original_tf_GLCMMS_energyd3.0A2.36std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A0.0std', 'PREDICT_original_tf_Gabor_std_F0.2_A2.36', 'PREDICT_original_tf_Gabor_entropy_F0.5_A0.79', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A0.0std', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57std', 'PREDICT_original_hf_std', 'PREDICT_original_tf_GLCM_energyd1.0A0.0', 'PREDICT_original_tf_GLCMMS_ASMd1.0A2.36std', 'PREDICT_original_tf_Gabor_std_F0.5_A0.79', 'PREDICT_original_tf_Gabor_energy_F0.2_A2.36', 'PREDICT_original_tf_GLCMMS_energyd1.0A0.79mean', 'PREDICT_original_tf_LBP_entropy_R8_P24', 'PREDICT_original_tf_GLCMMS_contrastd3.0A0.0std', 'PREDICT_original_tf_GLCM_contrastd3.0A0.0', 'PREDICT_original_tf_Gabor_quartile_range_F0.5_A1.57', 'PREDICT_original_tf_GLCMMS_dissimilarityd3.0A1.57std', 'PREDICT_original_tf_GLCMMS_correlationd1.0A0.0mean', 'PREDICT_original_tf_Gabor_min_F0.5_A2.36', 'PREDICT_original_hf_entropy', 'PREDICT_original_tf_GLCM_contrastd1.0A2.36', 'PREDICT_original_tf_GLCMMS_contrastd3.0A2.36std', 'PREDICT_original_tf_LBP_quartile_range_R8_P24', 'PREDICT_original_tf_Gabor_entropy_F0.5_A0.0', 'PREDICT_original_tf_GLCM_correlationd1.0A1.57', 'PREDICT_original_tf_GLCM_ASMd1.0A0.79', 'PREDICT_original_tf_GLCM_homogeneityd3.0A0.0', 'PREDICT_original_tf_GLCMMS_dissimilarityd3.0A2.36std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A1.57mean', 'PREDICT_original_tf_Gabor_entropy_F0.2_A1.57', 'PREDICT_original_tf_Gabor_range_F0.05_A0.0', 'PREDICT_original_tf_GLCMMS_correlationd1.0A1.57mean', 'PREDICT_original_tf_Gabor_std_F0.05_A2.36', 'PREDICT_original_vf_Frangi_inner_std_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCM_homogeneityd1.0A2.36', 'PREDICT_original_phasef_phasecong_kurtosis_WL3_N5', 'PREDICT_original_tf_GLCMMS_dissimilarityd1.0A0.79std', 'PREDICT_original_tf_GLCM_dissimilarityd3.0A2.36', 'PREDICT_original_tf_Gabor_energy_F0.5_A1.57', 'PREDICT_original_tf_Gabor_std_F0.2_A0.0', 'PREDICT_original_tf_Gabor_peak_F0.5_A0.79', 'PREDICT_original_tf_Gabor_std_F0.05_A1.57', 'PREDICT_original_tf_GLCM_correlationd3.0A1.57', 'PREDICT_original_tf_Gabor_max_F0.2_A1.57', 'PREDICT_original_vf_Frangi_edge_med ...
# Size of new training data set is:(149, 216); Old was: (149, 476)
# Optimal Alpha: 0.03853528593710531
# Number of selected features: 29
# Final Selected Features: ['PREDICT_original_sf_prax_avg_2.5D', 'PREDICT_original_sf_area_max_2.5D', 'PREDICT_original_sf_area_min_2.5D', 'PREDICT_original_logf_median_sigma1', 'PREDICT_original_logf_kurtosis_sigma1', 'PREDICT_original_logf_quartile_range_sigma1', 'PREDICT_original_logf_std_sigma5', 'PREDICT_original_logf_median_sigma10', 'PREDICT_original_logf_skewness_sigma10', 'PREDICT_original_tf_LBP_std_R3_P12', 'PREDICT_original_tf_LBP_mean_R8_P24', 'PREDICT_original_tf_LBP_kurtosis_R8_P24', 'PREDICT_original_tf_GLCMMS_homogeneityd3.0A2.36mean', 'PREDICT_original_tf_GLCMMS_correlationd3.0A1.57std', 'PREDICT_original_tf_Gabor_min_F0.05_A2.36', 'PREDICT_original_tf_Gabor_peak_F0.05_A2.36', 'PREDICT_original_tf_Gabor_quartile_range_F0.05_A2.36', 'PREDICT_original_tf_Gabor_median_F0.2_A0.0', 'PREDICT_original_tf_Gabor_skewness_F0.2_A0.0', 'PREDICT_original_tf_Gabor_kurtosis_F0.2_A0.79', 'PREDICT_original_tf_Gabor_mean_F0.2_A1.57', 'PREDICT_original_tf_Gabor_skewness_F0.5_A0.0', 'PREDICT_original_tf_Gabor_kurtosis_F0.5_A0.0', 'PREDICT_original_tf_Gabor_quartile_range_F0.5_A0.0', 'PREDICT_original_tf_Gabor_peak_position_F0.5_A0.79', 'PREDICT_original_vf_Frangi_full_entropy_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_vf_Frangi_inner_peak_position_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_phasef_phasecong_skewness_WL3_N5', 'PREDICT_original_phasef_phasesym_median_WL3_N5']
# Size of new training data set is:(149, 29)
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
#                  params  mean_train_score  std_train_score  mean_test_score  \
# 18  {'n_neighbors': 19}          0.809093         0.020929         0.750952
# 28  {'n_neighbors': 29}          0.782266         0.019506         0.743810
# 27  {'n_neighbors': 28}          0.783018         0.018439         0.743810
# 26  {'n_neighbors': 27}          0.784500         0.017970         0.743810
# 20  {'n_neighbors': 21}          0.812090         0.016505         0.737619
#
#     std_test_score  mean_score  std_score  ci_lower  ci_upper
# 18        0.096938    0.750952   0.102182  0.687620  0.814284
# 28        0.110857    0.743810   0.116854  0.671384  0.816235
# 27        0.114796    0.743810   0.121006  0.668811  0.818809
# 26        0.132750    0.743810   0.139931  0.657081  0.830538
# 20        0.102849    0.737619   0.108413  0.670425  0.804813
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
#                                                                                                                                                                params  \
# 527  {'bootstrap': True, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 120}
# 455  {'bootstrap': True, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 120}
# 491  {'bootstrap': True, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 120}
# 239   {'bootstrap': True, 'max_depth': 8, 'max_features': 'sqrt', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 120}
# 275   {'bootstrap': True, 'max_depth': 8, 'max_features': 'sqrt', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 120}
#
#      mean_score  std_score  ci_lower  ci_upper
# 527    0.805714   0.101010  0.743109  0.868320
# 455    0.805714   0.101010  0.743109  0.868320
# 491    0.805714   0.101010  0.743109  0.868320
# 239    0.799048   0.108258  0.731950  0.866145
# 275    0.799048   0.108258  0.731950  0.866145
# Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#                                                                    params  \
# 1654    {'C': 1, 'coef0': 1, 'degree': 1, 'gamma': 0.2, 'kernel': 'poly'}
# 1780    {'C': 1, 'coef0': 2, 'degree': 1, 'gamma': 0.2, 'kernel': 'poly'}
# 2155  {'C': 2, 'coef0': 0.5, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
# 1276  {'C': 1, 'coef0': 0.0, 'degree': 1, 'gamma': 0.2, 'kernel': 'poly'}
# 2407    {'C': 2, 'coef0': 2, 'degree': 1, 'gamma': 0.1, 'kernel': 'poly'}
#
#       mean_score  std_score  ci_lower  ci_upper
# 1654    0.879048   0.098571  0.817954  0.940142
# 1780    0.879048   0.098571  0.817954  0.940142
# 2155    0.879048   0.098571  0.817954  0.940142
# 1276    0.879048   0.098571  0.817954  0.940142
# 2407    0.879048   0.098571  0.817954  0.940142
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
#                params  mean_train_score  std_train_score  mean_test_score  \
# 0  {'n_neighbors': 1}          1.000000         0.000000         0.679524
# 3  {'n_neighbors': 4}          0.780017         0.011638         0.665238
# 1  {'n_neighbors': 2}          0.818049         0.011611         0.665238
# 4  {'n_neighbors': 5}          0.810619         0.024052         0.651429
# 2  {'n_neighbors': 3}          0.821017         0.026138         0.644762
#
#    std_test_score  mean_score  std_score  ci_lower  ci_upper
# 0        0.113650    0.679524   0.119798  0.605274  0.753774
# 3        0.087392    0.665238   0.092120  0.608143  0.722333
# 1        0.097032    0.665238   0.102281  0.601845  0.728631
# 4        0.113505    0.651429   0.119645  0.577273  0.725584
# 2        0.082813    0.644762   0.087293  0.590658  0.698866
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
#                                                                                                                                                                params  \
# 545  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 120}
# 617  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 120}
# 581  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 120}
# 616  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 115}
# 544  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 115}
#
#      mean_score  std_score  ci_lower  ci_upper
# 545    0.717619   0.144506  0.628055  0.807183
# 617    0.717619   0.144506  0.628055  0.807183
# 581    0.717619   0.144506  0.628055  0.807183
# 616    0.710476   0.143540  0.621511  0.799441
# 544    0.710476   0.143540  0.621511  0.799441
# Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#                                                                      params  \
# 2653  {'C': 3, 'coef0': 0.01, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# 2779   {'C': 3, 'coef0': 0.5, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# 2527   {'C': 3, 'coef0': 0.0, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# 2905     {'C': 3, 'coef0': 1, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
# 3031     {'C': 3, 'coef0': 2, 'degree': 1, 'gamma': 0.01, 'kernel': 'poly'}
#
#       mean_score  std_score  ci_lower  ci_upper
# 2653    0.778571   0.088924  0.723457  0.833686
# 2779    0.778571   0.088924  0.723457  0.833686
# 2527    0.778571   0.088924  0.723457  0.833686
# 2905    0.778571   0.088924  0.723457  0.833686
# 3031    0.778571   0.088924  0.723457  0.833686
# Dropped features due to high correlation:
# {'PREDICT_original_vf_Frangi_inner_kurtosis_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_Gabor_range_F0.5_A1.57', 'PREDICT_original_tf_GLCMMS_contrastd3.0A0.79std', 'PREDICT_original_phasef_phasecong_range_WL3_N5', 'PREDICT_original_tf_GLCMMS_energyd3.0A0.0std', 'PREDICT_original_tf_GLCMMS_contrastd1.0A1.57std', 'PREDICT_original_tf_GLCMMS_correlationd3.0A0.79mean', 'PREDICT_original_phasef_phasesym_std_WL3_N5', 'PREDICT_original_phasef_phasecong_quartile_range_WL3_N5', 'PREDICT_original_tf_GLCMMS_ASMd3.0A0.79mean', 'PREDICT_original_tf_Gabor_range_F0.5_A0.0', 'PREDICT_original_tf_GLCMMS_dissimilarityd3.0A0.79mean', 'PREDICT_original_logf_energy_sigma10', 'PREDICT_original_tf_Gabor_entropy_F0.2_A0.79', 'PREDICT_original_vf_Frangi_edge_quartile_range_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCMMS_ASMd3.0A0.0std', 'PREDICT_original_tf_Gabor_range_F0.05_A2.36', 'PREDICT_original_tf_Gabor_peak_F0.5_A1.57', 'PREDICT_original_tf_Gabor_entropy_F0.2_A2.36', 'PREDICT_original_tf_GLCMMS_contrastd1.0A2.36std', 'PREDICT_original_logf_entropy_sigma1', 'PREDICT_original_tf_Gabor_entropy_F0.05_A1.57', 'PREDICT_original_tf_GLCM_dissimilarityd3.0A0.0', 'PREDICT_original_tf_GLCM_ASMd1.0A2.36', 'PREDICT_original_tf_GLCMMS_energyd1.0A1.57std', 'PREDICT_original_phasef_monogenic_peak_position_WL3_N5', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57mean', 'PREDICT_original_tf_GLCMMS_correlationd1.0A0.79mean', 'PREDICT_original_tf_GLCM_dissimilarityd1.0A0.0', 'PREDICT_original_tf_GLCMMS_correlationd1.0A2.36mean', 'PREDICT_original_tf_Gabor_std_F0.05_A0.0', 'PREDICT_original_tf_GLCM_homogeneityd1.0A1.57', 'PREDICT_original_tf_GLCMMS_contrastd1.0A0.79std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A1.57std', 'PREDICT_original_tf_GLCM_ASMd3.0A1.57', 'PREDICT_original_tf_Gabor_std_F0.2_A0.79', 'PREDICT_original_tf_GLCMMS_correlationd1.0A1.57std', 'PREDICT_original_tf_GLCMMS_energyd3.0A2.36std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A0.0std', 'PREDICT_original_tf_Gabor_std_F0.2_A2.36', 'PREDICT_original_tf_Gabor_entropy_F0.5_A0.79', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A0.0std', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57std', 'PREDICT_original_tf_GLCM_energyd1.0A0.0', 'PREDICT_original_tf_GLCMMS_ASMd1.0A2.36std', 'PREDICT_original_tf_Gabor_std_F0.5_A0.79', 'PREDICT_original_tf_Gabor_energy_F0.2_A2.36', 'PREDICT_original_tf_GLCMMS_energyd1.0A0.79mean', 'PREDICT_original_tf_LBP_entropy_R8_P24', 'PREDICT_original_tf_GLCMMS_contrastd3.0A0.0std', 'PREDICT_original_tf_GLCM_contrastd3.0A0.0', 'PREDICT_original_tf_Gabor_quartile_range_F0.5_A1.57', 'PREDICT_original_tf_GLCMMS_correlationd1.0A0.0mean', 'PREDICT_original_tf_Gabor_min_F0.5_A2.36', 'PREDICT_original_hf_entropy', 'PREDICT_original_tf_GLCM_contrastd1.0A2.36', 'PREDICT_original_tf_GLCMMS_contrastd3.0A2.36std', 'PREDICT_original_tf_LBP_quartile_range_R8_P24', 'PREDICT_original_tf_Gabor_entropy_F0.5_A0.0', 'PREDICT_original_tf_GLCM_correlationd1.0A1.57', 'PREDICT_original_tf_GLCM_ASMd1.0A0.79', 'PREDICT_original_tf_GLCM_homogeneityd3.0A0.0', 'PREDICT_original_tf_GLCMMS_ASMd1.0A1.57mean', 'PREDICT_original_tf_Gabor_entropy_F0.2_A1.57', 'PREDICT_original_tf_Gabor_range_F0.05_A0.0', 'PREDICT_original_tf_GLCMMS_correlationd1.0A1.57mean', 'PREDICT_original_tf_Gabor_std_F0.05_A2.36', 'PREDICT_original_vf_Frangi_inner_std_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCM_homogeneityd1.0A2.36', 'PREDICT_original_phasef_phasecong_kurtosis_WL3_N5', 'PREDICT_original_tf_GLCMMS_dissimilarityd1.0A0.79std', 'PREDICT_original_tf_GLCM_dissimilarityd3.0A2.36', 'PREDICT_original_tf_Gabor_energy_F0.5_A1.57', 'PREDICT_original_tf_Gabor_std_F0.2_A0.0', 'PREDICT_original_tf_Gabor_peak_F0.5_A0.79', 'PREDICT_original_tf_Gabor_std_F0.05_A1.57', 'PREDICT_original_tf_GLCM_correlationd3.0A1.57', 'PREDICT_original_tf_Gabor_max_F0.2_A1.57', 'PREDICT_original_vf_Frangi_edge_median_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_Gabor_std_F0.05_A0.79', 'PREDICT_original_tf_GLCMMS_contrastd1.0A2.36mean', 'PREDICT_original_tf_GLCMMS_correlat ...
# Size of new training data set is:(149, 215); Old was: (149, 475)
# Optimal Alpha: 0.03511191734215135
# Number of selected features: 29
# Final Selected Features: ['PREDICT_original_sf_roughness_std_2.5D', 'PREDICT_original_sf_area_max_2.5D', 'PREDICT_original_sf_area_min_2.5D', 'PREDICT_original_of_theta_z', 'PREDICT_original_hf_skewness', 'PREDICT_original_logf_median_sigma1', 'PREDICT_original_logf_kurtosis_sigma1', 'PREDICT_original_logf_peak_position_sigma1', 'PREDICT_original_logf_quartile_range_sigma1', 'PREDICT_original_logf_std_sigma5', 'PREDICT_original_logf_median_sigma10', 'PREDICT_original_logf_skewness_sigma10', 'PREDICT_original_tf_LBP_std_R3_P12', 'PREDICT_original_tf_GLCMMS_contrastd3.0A1.57mean', 'PREDICT_original_tf_GLCMMS_correlationd3.0A1.57std', 'PREDICT_original_tf_Gabor_min_F0.05_A0.79', 'PREDICT_original_tf_Gabor_skewness_F0.05_A0.79', 'PREDICT_original_tf_Gabor_kurtosis_F0.05_A0.79', 'PREDICT_original_tf_Gabor_min_F0.05_A2.36', 'PREDICT_original_tf_Gabor_peak_F0.05_A2.36', 'PREDICT_original_tf_Gabor_skewness_F0.2_A0.0', 'PREDICT_original_tf_Gabor_kurtosis_F0.2_A0.79', 'PREDICT_original_tf_Gabor_peak_position_F0.2_A0.79', 'PREDICT_original_tf_Gabor_mean_F0.2_A1.57', 'PREDICT_original_tf_Gabor_skewness_F0.5_A0.0', 'PREDICT_original_tf_Gabor_kurtosis_F0.5_A0.0', 'PREDICT_original_tf_Gabor_kurtosis_F0.5_A1.57', 'PREDICT_original_phasef_phasecong_entropy_WL3_N5', 'PREDICT_original_phasef_phasesym_median_WL3_N5']
# Size of new training data set is:(149, 29)
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
#                  params  mean_train_score  std_train_score  mean_test_score  \
# 14  {'n_neighbors': 15}          0.853836         0.015034         0.860000
# 16  {'n_neighbors': 17}          0.856833         0.018136         0.852381
# 15  {'n_neighbors': 16}          0.844876         0.022183         0.845714
# 26  {'n_neighbors': 27}          0.838933         0.017334         0.839048
# 22  {'n_neighbors': 23}          0.853101         0.017296         0.839048
#
#     std_test_score  mean_score  std_score  ci_lower  ci_upper
# 14        0.100885    0.860000   0.106342  0.794090  0.925910
# 16        0.088346    0.852381   0.093125  0.794663  0.910099
# 15        0.094358    0.845714   0.099462  0.784068  0.907360
# 26        0.085125    0.839048   0.089730  0.783434  0.894662
# 22        0.073949    0.839048   0.077949  0.790735  0.887360
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
#                                                                                                                                                               params  \
# 324  {'bootstrap': True, 'max_depth': 8, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 110}
# 396  {'bootstrap': True, 'max_depth': 8, 'max_features': 'log2', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 110}
# 360  {'bootstrap': True, 'max_depth': 8, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 110}
# 326  {'bootstrap': True, 'max_depth': 8, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 120}
# 362  {'bootstrap': True, 'max_depth': 8, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 120}
#
#      mean_score  std_score  ci_lower  ci_upper
# 324    0.845238   0.114269  0.774415  0.916062
# 396    0.845238   0.114269  0.774415  0.916062
# 360    0.845238   0.114269  0.774415  0.916062
# 326    0.831905   0.110567  0.763376  0.900433
# 362    0.831905   0.110567  0.763376  0.900433
# Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#                                                                      params  \
# 2633   {'C': 3, 'coef0': 0.0, 'degree': 15, 'gamma': 0.01, 'kernel': 'rbf'}
# 2948      {'C': 3, 'coef0': 1, 'degree': 5, 'gamma': 0.01, 'kernel': 'rbf'}
# 2528    {'C': 3, 'coef0': 0.0, 'degree': 1, 'gamma': 0.01, 'kernel': 'rbf'}
# 2549    {'C': 3, 'coef0': 0.0, 'degree': 3, 'gamma': 0.01, 'kernel': 'rbf'}
# 649   {'C': 0.1, 'coef0': 0.0, 'degree': 1, 'gamma': 0.5, 'kernel': 'poly'}
#
#       mean_score  std_score  ci_lower  ci_upper
# 2633    0.899048     0.0654  0.858513  0.939582
# 2948    0.899048     0.0654  0.858513  0.939582
# 2528    0.899048     0.0654  0.858513  0.939582
# 2549    0.899048     0.0654  0.858513  0.939582
# 649     0.899048     0.0654  0.858513  0.939582
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
#                  params  mean_train_score  std_train_score  mean_test_score  \
# 24  {'n_neighbors': 25}          0.684577         0.024570         0.678571
# 28  {'n_neighbors': 29}          0.708419         0.039460         0.678571
# 0    {'n_neighbors': 1}          1.000000         0.000000         0.678571
# 29  {'n_neighbors': 30}          0.697236         0.028204         0.671905
# 5    {'n_neighbors': 6}          0.744201         0.014862         0.671429
#
#     std_test_score  mean_score  std_score  ci_lower  ci_upper
# 24        0.091578    0.678571   0.096532  0.618741  0.738402
# 28        0.156162    0.678571   0.164609  0.576547  0.780596
# 0         0.124490    0.678571   0.131224  0.597240  0.759903
# 29        0.140043    0.671905   0.147618  0.580412  0.763398
# 5         0.095357    0.671429   0.100515  0.609130  0.733727
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
#                                                                                                                                                                params  \
# 256   {'bootstrap': True, 'max_depth': 8, 'max_features': 'sqrt', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 115}
# 220   {'bootstrap': True, 'max_depth': 8, 'max_features': 'sqrt', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 115}
# 292   {'bootstrap': True, 'max_depth': 8, 'max_features': 'sqrt', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 115}
# 444  {'bootstrap': True, 'max_depth': 13, 'max_features': 'sqrt', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 110}
# 303   {'bootstrap': True, 'max_depth': 8, 'max_features': 'sqrt', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 110}
#
#      mean_score  std_score  ci_lower  ci_upper
# 256    0.799048   0.125182  0.721461  0.876635
# 220    0.799048   0.125182  0.721461  0.876635
# 292    0.799048   0.125182  0.721461  0.876635
# 444    0.798571   0.104329  0.733909  0.863234
# 303    0.798571   0.094389  0.740070  0.857073
# Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#                                                                         params  \
# 2773   {'C': 3, 'coef0': 0.5, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 2524    {'C': 3, 'coef0': 0.0, 'degree': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 3028      {'C': 3, 'coef0': 2, 'degree': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 3025     {'C': 3, 'coef0': 2, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 2647  {'C': 3, 'coef0': 0.01, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
#
#       mean_score  std_score  ci_lower  ci_upper
# 2773    0.818571   0.113898  0.747978  0.889165
# 2524    0.818571   0.113898  0.747978  0.889165
# 3028    0.818571   0.113898  0.747978  0.889165
# 3025    0.818571   0.113898  0.747978  0.889165
# 2647    0.818571   0.113898  0.747978  0.889165
# Dropped features due to high correlation:
# {'PREDICT_original_vf_Frangi_inner_kurtosis_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_Gabor_range_F0.5_A1.57', 'PREDICT_original_tf_GLCMMS_contrastd3.0A0.79std', 'PREDICT_original_tf_GLCMMS_energyd3.0A0.0std', 'PREDICT_original_tf_GLCMMS_contrastd1.0A1.57std', 'PREDICT_original_tf_GLCMMS_correlationd3.0A0.79mean', 'PREDICT_original_phasef_phasesym_std_WL3_N5', 'PREDICT_original_phasef_phasecong_quartile_range_WL3_N5', 'PREDICT_original_tf_GLCMMS_ASMd3.0A0.79mean', 'PREDICT_original_tf_Gabor_range_F0.5_A0.0', 'PREDICT_original_tf_GLCMMS_dissimilarityd3.0A0.79mean', 'PREDICT_original_tf_Gabor_entropy_F0.2_A0.79', 'PREDICT_original_vf_Frangi_edge_quartile_range_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCMMS_ASMd3.0A0.0std', 'PREDICT_original_tf_Gabor_range_F0.05_A2.36', 'PREDICT_original_tf_Gabor_peak_F0.5_A1.57', 'PREDICT_original_tf_Gabor_entropy_F0.2_A2.36', 'PREDICT_original_tf_GLCMMS_contrastd1.0A2.36std', 'PREDICT_original_logf_entropy_sigma1', 'PREDICT_original_tf_Gabor_entropy_F0.05_A1.57', 'PREDICT_original_tf_GLCM_dissimilarityd3.0A0.0', 'PREDICT_original_tf_GLCM_ASMd1.0A2.36', 'PREDICT_original_tf_GLCMMS_energyd1.0A1.57std', 'PREDICT_original_phasef_monogenic_peak_position_WL3_N5', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57mean', 'PREDICT_original_tf_GLCMMS_correlationd1.0A0.79mean', 'PREDICT_original_tf_GLCM_dissimilarityd1.0A0.0', 'PREDICT_original_tf_GLCMMS_correlationd1.0A2.36mean', 'PREDICT_original_tf_Gabor_std_F0.05_A0.0', 'PREDICT_original_tf_GLCM_homogeneityd1.0A1.57', 'PREDICT_original_tf_GLCMMS_contrastd1.0A0.79std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A1.57std', 'PREDICT_original_tf_GLCM_ASMd3.0A1.57', 'PREDICT_original_tf_Gabor_std_F0.2_A0.79', 'PREDICT_original_tf_GLCMMS_correlationd1.0A1.57std', 'PREDICT_original_tf_GLCMMS_energyd3.0A2.36std', 'PREDICT_original_tf_GLCMMS_ASMd1.0A0.0std', 'PREDICT_original_tf_Gabor_std_F0.2_A2.36', 'PREDICT_original_tf_Gabor_entropy_F0.5_A0.79', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A0.0std', 'PREDICT_original_tf_GLCMMS_homogeneityd1.0A1.57std', 'PREDICT_original_hf_std', 'PREDICT_original_tf_GLCM_energyd1.0A0.0', 'PREDICT_original_tf_GLCMMS_ASMd1.0A2.36std', 'PREDICT_original_tf_Gabor_std_F0.5_A0.79', 'PREDICT_original_tf_Gabor_energy_F0.2_A2.36', 'PREDICT_original_tf_GLCMMS_energyd1.0A0.79mean', 'PREDICT_original_tf_LBP_entropy_R8_P24', 'PREDICT_original_tf_GLCMMS_contrastd3.0A0.0std', 'PREDICT_original_tf_GLCM_contrastd3.0A0.0', 'PREDICT_original_tf_Gabor_quartile_range_F0.5_A1.57', 'PREDICT_original_tf_GLCMMS_correlationd1.0A0.0mean', 'PREDICT_original_tf_Gabor_min_F0.5_A2.36', 'PREDICT_original_hf_entropy', 'PREDICT_original_tf_GLCM_contrastd1.0A2.36', 'PREDICT_original_tf_GLCMMS_contrastd3.0A2.36std', 'PREDICT_original_tf_LBP_quartile_range_R8_P24', 'PREDICT_original_tf_Gabor_entropy_F0.5_A0.0', 'PREDICT_original_tf_GLCM_correlationd1.0A1.57', 'PREDICT_original_tf_GLCM_ASMd1.0A0.79', 'PREDICT_original_tf_GLCM_homogeneityd3.0A0.0', 'PREDICT_original_tf_GLCMMS_ASMd1.0A1.57mean', 'PREDICT_original_tf_Gabor_entropy_F0.2_A1.57', 'PREDICT_original_tf_Gabor_range_F0.05_A0.0', 'PREDICT_original_tf_GLCMMS_correlationd1.0A1.57mean', 'PREDICT_original_tf_Gabor_std_F0.05_A2.36', 'PREDICT_original_vf_Frangi_inner_std_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_GLCM_homogeneityd1.0A2.36', 'PREDICT_original_phasef_phasecong_kurtosis_WL3_N5', 'PREDICT_original_tf_GLCMMS_dissimilarityd1.0A0.79std', 'PREDICT_original_tf_GLCM_dissimilarityd3.0A2.36', 'PREDICT_original_tf_Gabor_energy_F0.5_A1.57', 'PREDICT_original_tf_Gabor_std_F0.2_A0.0', 'PREDICT_original_tf_Gabor_peak_F0.5_A0.79', 'PREDICT_original_tf_Gabor_std_F0.05_A1.57', 'PREDICT_original_tf_GLCM_correlationd3.0A1.57', 'PREDICT_original_tf_Gabor_max_F0.2_A1.57', 'PREDICT_original_vf_Frangi_edge_median_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_tf_Gabor_std_F0.05_A0.79', 'PREDICT_original_tf_GLCMMS_contrastd1.0A2.36mean', 'PREDICT_original_tf_GLCMMS_correlationd3.0A0.79std', 'PREDICT_original_phasef_monogenic_entropy_WL ...
# Size of new training data set is:(149, 222); Old was: (149, 474)
# Optimal Alpha: 0.03199267137797385
# Number of selected features: 31
# Final Selected Features: ['PREDICT_original_sf_cvar_avg_2.5D', 'PREDICT_original_sf_area_min_2.5D', 'PREDICT_original_logf_median_sigma1', 'PREDICT_original_logf_kurtosis_sigma1', 'PREDICT_original_logf_quartile_range_sigma1', 'PREDICT_original_logf_std_sigma5', 'PREDICT_original_logf_quartile_range_sigma5', 'PREDICT_original_logf_skewness_sigma10', 'PREDICT_original_tf_LBP_std_R3_P12', 'PREDICT_original_tf_LBP_energy_R3_P12', 'PREDICT_original_tf_LBP_mean_R8_P24', 'PREDICT_original_tf_LBP_kurtosis_R8_P24', 'PREDICT_original_tf_GLCMMS_correlationd3.0A0.0std', 'PREDICT_original_tf_GLCMMS_correlationd3.0A1.57std', 'PREDICT_original_tf_Gabor_kurtosis_F0.05_A0.79', 'PREDICT_original_tf_Gabor_peak_position_F0.05_A1.57', 'PREDICT_original_tf_Gabor_min_F0.05_A2.36', 'PREDICT_original_tf_Gabor_peak_F0.05_A2.36', 'PREDICT_original_tf_Gabor_skewness_F0.2_A0.0', 'PREDICT_original_tf_Gabor_kurtosis_F0.2_A0.0', 'PREDICT_original_tf_Gabor_kurtosis_F0.2_A0.79', 'PREDICT_original_tf_Gabor_mean_F0.2_A1.57', 'PREDICT_original_tf_Gabor_peak_F0.2_A1.57', 'PREDICT_original_tf_Gabor_mean_F0.2_A2.36', 'PREDICT_original_tf_Gabor_skewness_F0.5_A0.0', 'PREDICT_original_tf_Gabor_peak_position_F0.5_A0.79', 'PREDICT_original_tf_Gabor_kurtosis_F0.5_A1.57', 'PREDICT_original_vf_Frangi_inner_peak_position_SR(1.0, 10.0)_SS2.0', 'PREDICT_original_phasef_monogenic_energy_WL3_N5', 'PREDICT_original_phasef_phasecong_entropy_WL3_N5', 'PREDICT_original_phasef_phasesym_median_WL3_N5']
# Size of new training data set is:(149, 31)
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
#                  params  mean_train_score  std_train_score  mean_test_score  \
# 25  {'n_neighbors': 26}          0.841133         0.019370         0.791429
# 15  {'n_neighbors': 16}          0.850122         0.018326         0.791429
# 21  {'n_neighbors': 22}          0.853814         0.023054         0.778571
# 26  {'n_neighbors': 27}          0.827706         0.023886         0.778095
# 24  {'n_neighbors': 25}          0.840381         0.019436         0.778095
#
#     std_test_score  mean_score  std_score  ci_lower  ci_upper
# 25        0.082967    0.791429   0.087454  0.737225  0.845632
# 15        0.139025    0.791429   0.146545  0.700601  0.882256
# 21        0.098911    0.778571   0.104262  0.713951  0.843192
# 26        0.068552    0.778095   0.072260  0.733309  0.822881
# 24        0.090856    0.778095   0.095771  0.718737  0.837454
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
#                                                                                                                                                                params  \
# 633  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 110}
# 597  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 110}
# 561  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 110}
# 613  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 115}
# 577  {'bootstrap': True, 'max_depth': 13, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 115}
#
#      mean_score  std_score  ci_lower  ci_upper
# 633    0.804286   0.114428  0.733364  0.875208
# 597    0.804286   0.114428  0.733364  0.875208
# 561    0.804286   0.114428  0.733364  0.875208
# 613    0.803810   0.136486  0.719216  0.888403
# 577    0.803810   0.136486  0.719216  0.888403
# Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#                                                                         params  \
# 3658      {'C': 5, 'coef0': 2, 'degree': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 3151   {'C': 5, 'coef0': 0.0, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 3406    {'C': 5, 'coef0': 0.5, 'degree': 1, 'gamma': 'auto', 'kernel': 'poly'}
# 3403   {'C': 5, 'coef0': 0.5, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
# 3277  {'C': 5, 'coef0': 0.01, 'degree': 1, 'gamma': 'scale', 'kernel': 'poly'}
#
#       mean_score  std_score  ci_lower  ci_upper
# 3658    0.878571   0.099767  0.816737  0.940406
# 3151    0.878571   0.099767  0.816737  0.940406
# 3406    0.878571   0.099767  0.816737  0.940406
# 3403    0.878571   0.099767  0.816737  0.940406
# 3277    0.878571   0.099767  0.816737  0.940406
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
#                  params  mean_train_score  std_train_score  mean_test_score  \
# 3    {'n_neighbors': 4}          0.805357         0.009921         0.678095
# 4    {'n_neighbors': 5}          0.798662         0.017281         0.678095
# 2    {'n_neighbors': 3}          0.829994         0.018938         0.671905
# 5    {'n_neighbors': 6}          0.780011         0.009660         0.665238
# 25  {'n_neighbors': 26}          0.682322         0.023464         0.651429
#
#     std_test_score  mean_score  std_score  ci_lower  ci_upper
# 3         0.056633    0.678095   0.059696  0.641096  0.715095
# 4         0.076642    0.678095   0.080787  0.628024  0.728167
# 2         0.079238    0.671905   0.083524  0.620137  0.723673
# 5         0.063889    0.665238   0.067345  0.623498  0.706978
# 25        0.128215    0.651429   0.135150  0.567663  0.735194
# Fitting 10 folds for each of 648 candidates, totalling 6480 fits
#                                                                                                                                                               params  \
# 214  {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_impurity_decrease': 2e-05, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 115}
# 132  {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_impurity_decrease': 1e-05, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 110}
# 174  {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 110}
# 175  {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 115}
# 171  {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'min_impurity_decrease': 5e-06, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 110}
#
#      mean_score  std_score  ci_lower  ci_upper
# 214    0.779048   0.082393  0.727981  0.830114
# 132    0.779048   0.082393  0.727981  0.830114
# 174    0.779048   0.082393  0.727981  0.830114
# 175    0.779048   0.082393  0.727981  0.830114
# 171    0.779048   0.082393  0.727981  0.830114
# Fitting 10 folds for each of 5040 candidates, totalling 50400 fits
#                                                                        params  \
# 1033   {'C': 0.1, 'coef0': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 1030  {'C': 0.1, 'coef0': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 532     {'C': 0.01, 'coef0': 2, 'degree': 3, 'gamma': 0.01, 'kernel': 'poly'}
# 3260   {'C': 5, 'coef0': 0.0, 'degree': 15, 'gamma': 'auto', 'kernel': 'rbf'}
# 4244   {'C': 10, 'coef0': 1, 'degree': 12, 'gamma': 'scale', 'kernel': 'rbf'}
#
#       mean_score  std_score  ci_lower  ci_upper
# 1033    0.805238   0.080075  0.755608  0.854868
# 1030    0.805238   0.086021  0.751923  0.858553
# 532     0.798095   0.085041  0.745387  0.850804
# 3260    0.791429   0.060808  0.753740  0.829117
# 4244    0.791429   0.060808  0.753740  0.829117
#     KNN_Acc   KNN_AUC    RF_Acc    RF_AUC   SVM_Acc   SVM_AUC  KNN_LASSO_Acc  \
# 0  0.594595  0.594118  0.621622  0.623529  0.864865  0.866176       0.729730
# 1  0.567568  0.568713  0.594595  0.595029  0.756757  0.757310       0.756757
# 2  0.702703  0.788462  0.729730  0.807692  0.702703  0.736014       0.729730
# 3  0.783784  0.777941  0.783784  0.791176  0.864865  0.861765       0.675676
# 4  0.729730  0.724702  0.621622  0.629464  0.675676  0.684524       0.702703
#
#    KNN_LASSO_AUC  RF_LASSO_Acc  RF_LASSO_AUC  SVM_LASSO_Acc  SVM_LASSO_AUC
# 0       0.732353      0.864865      0.866176       0.810811       0.807353
# 1       0.760234      0.702703      0.701754       0.756757       0.757310
# 2       0.807692      0.702703      0.736014       0.810811       0.839161
# 3       0.677941      0.702703      0.702941       0.810811       0.811765
# 4       0.715774      0.756757      0.778274       0.648649       0.645833
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 118
#     116 plt.figure(figsize=(8, 6))
#     117 for i, (fpr, tpr) in enumerate(curves):
# --> 118     roc_auc = auc(fpr, tpr)
#     119     plt.plot(fpr, tpr, lw=2, label=f'Split {i+1} (AUC = {roc_auc:.2f})')
#     120 plt.plot([0, 1], [0, 1], 'k--', lw=1)
#
# TypeError: 'numpy.float64' object is not callable

# %% [markdown]
# ### plotten ROC curves

# %%
# === Plotting ROC curves ===
from sklearn.metrics import auc

for label, curves in roc_data.items():
    plt.figure(figsize=(8, 6))
    for i, (fpr, tpr) in enumerate(curves):
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f'Split {i+1} (AUC = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--', lw=1)
    plt.title(f'ROC Curve - {label}')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Learning curve

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.neighbors import KNeighborsClassifier

 ### Preprocessing all the data together (needed for learning curves)
label_binary_lc = determining_labels(data)
full_data_clean_lc = handling_missing_data(data)
data_clean_lc = delete_no_varation(full_data_clean_lc, features_no_variation)
data_normalized_df_lc = standardize_data(data_clean_lc, normal_distributed)

# Model 
model = KNeighborsClassifier(n_neighbors=21)

# Define sizes of the training set to use (10 steps from 10% to 100%)
train_sizes = np.linspace(0.1, 1.0, 10)

# Get learning curve scores
train_sizes, train_scores, test_scores = learning_curve(
    estimator=model,
    X=training_data_selected_final, # complete dataset after complete preprocessing
    y=label_training_array, # labels of the complete dataset 
    train_sizes=train_sizes,
    cv=5,
    scoring='accuracy',
    n_jobs=-1,
    return_times=False
)

# Calculate means and standard deviations
train_mean = np.mean(train_scores, axis=1)
train_std = np.std(train_scores, axis=1)
test_mean = np.mean(test_scores, axis=1)
test_std = np.std(test_scores, axis=1)

# Plot
plt.figure(figsize=(10, 6))
plt.title(f"Learning Curve for {model.__class__}")
plt.plot(train_sizes, train_mean, 'o-', color="red", label="Training score")
plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.2, color="red")
plt.plot(train_sizes, test_mean, 'o-', color="green", label="Test set score")
plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.2, color="green")
plt.xlabel("Training Set Size")
plt.ylabel("Score")
plt.grid(True)
plt.legend(loc="best")
plt.ylim(0.3, 1.05)
plt.tight_layout()
plt.show()
